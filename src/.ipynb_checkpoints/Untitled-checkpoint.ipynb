# %%
pip install datetime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import datetime

finl_data = pd.read_csv("../data/finland_samples_202304.csv")
uk_data = pd.read_csv("../data/uk_sepa_samples_202312.csv")

# %%
uk_data.loc[:,"Site ID"]
uk_data.Site ID
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18340\4281334721.py in ?()
# ----> 1 uk_data.Date/Time
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
grupos = uk_data.groupby('Site )
# Out:
#   Cell In[9], line 1
#     grupos = uk_data.groupby('Site ID)
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
now =datetime.datetime.now()
now
# Out:
# datetime.datetime(2024, 10, 31, 20, 4, 17, 20082)

# %%
uk_data = uk_data.dropna()

# %%
colu = uk_data.columns.str.replace(" ","_") 
uk_data.columns=colu

# %%
fechas = pd.to_datetime(uk_data.loc[:,"Date/Time"])

# %%
time = fechas.astype('int64') // 1e9

# %%
uk_data["Date_epoch"] = time

# %%
df_pivot = uk_data.pivot(index='Site_ID', columns='Date/Time', values='Target_1_Concentration')
df_pivot_NaN = df_pivot

# %%
df_pivot.interpolate(method='linear', axis=1, inplace=True)

# %%
df_pivot
# Out:
# Date/Time      2020-05-28  2020-05-29  2020-06-01  2020-06-02  2020-06-03  \
# Site_ID
# UK_SC_Site1           NaN         NaN         0.0         0.0         0.0
# UK_SC_Site10          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site100         NaN         NaN         NaN         NaN         NaN
# UK_SC_Site101         NaN         NaN         NaN         NaN         NaN
# UK_SC_Site102         NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# UK_SC_Site95          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site96          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site97          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site98          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site99          NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
df_pivot_NaN
# Out:
# Date/Time      2020-05-28  2020-05-29  2020-06-01  2020-06-02  2020-06-03  \
# Site_ID
# UK_SC_Site1           NaN         NaN         0.0         0.0         0.0
# UK_SC_Site10          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site100         NaN         NaN         NaN         NaN         NaN
# UK_SC_Site101         NaN         NaN         NaN         NaN         NaN
# UK_SC_Site102         NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# UK_SC_Site95          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site96          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site97          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site98          NaN         NaN         NaN         NaN         NaN
# UK_SC_Site99          NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
uk_data
# Out:
#              Site_ID            Date/Time Target_1_Result  \
# 0       UK_SC_Site24  2021-02-19 00:00:00        presence
# 1       UK_SC_Site24  2021-02-23 00:00:00        presence
# 2       UK_SC_Site24  2021-03-01 00:00:00        presence
# 3       UK_SC_Site24  2021-03-08 00:00:00        presence
# 4       UK_SC_Site24  2021-03-15 00:00:00        presence
# ...              ...                  ...             ...
# 23557  UK_SC_Site102  2023-10-02 00:00:00        presence
# 23558  UK_SC_Site102  2023-10-16 00:00:00        presence
# 23559  UK_SC_Site102  2023-10-30 00:00:00        presence
# 23560  UK_SC_Site102  2023-11-06 00:00:00        presence
# 23561  UK_SC_Site102  2023-11-27 00:00:00        presence
#
#        Target_1_Concentration Target_1 Target_1_Units  \
# 0                 85619.30021       N1           gc/L
# 1                 75691.38668       N1           gc/L
# 2                 42624.29796       N1           gc/L
# ...

# %%
grupos = uk_data.groupby(level=0)

# %%
coords = pd.read_csv("../data/monitoring-sites.csv")
coords
# Out:
#            site_id                        facility_name admin0  admin1  \
# 0    UK_SC_Site118         Wick, Highland, Scotland, GB     GB     NaN
# 1    UK_SC_Site117       Thurso, Highland, Scotland, GB     GB     NaN
# 2    UK_SC_Site116      Persley, Grampian, Scotland, GB     GB     NaN
# 3    UK_SC_Site115     Newbridge, Lothian, Scotland, GB     GB     NaN
# 4    UK_SC_Site114      Montrose, Tayside, Scotland, GB     GB     NaN
# ..             ...                                  ...    ...     ...
# 113    UK_SC_Site2    Allers, Lanarkshire, Scotland, GB    NaN     NaN
# 114    UK_SC_Site1   Allanfearn, Highland, Scotland, GB    NaN     NaN
# 115   UK_SC_Site11      Bathgate, Lothian, Scotland, GB    NaN     NaN
# 116   UK_SC_Site12    Biggar, Lanarkshire, Scotland, GB    NaN     NaN
# 117   UK_SC_Site22  Carbarns, Lanarkshire, Scotland, GB    NaN     NaN
#
#      admin2  address_line  postal_code   latitude  longitude  contact_person  \
# ...
